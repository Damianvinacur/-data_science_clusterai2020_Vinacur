# %% [markdown]
# ## Librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.svm import LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression , Ridge

from sklearn.model_selection import GridSearchCV

# %%
pwd
# Out:
# 'C:\\Users\\Mariela\\Desktop\\Dami\\ciencia de datos\\tp'

# %% [markdown]
# ## Datasets

# %%
#Lucas
#tv_16= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\TV-2016.csv', delimiter=';', encoding='latin-1')
##tv_17= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\TV-2017.csv', delimiter=';', encoding='latin-1')
#tv_18= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\TV-2018.csv', delimiter=',')
#tv_19= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\TV-2019.csv', delimiter=',')
#radios_16= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Radios-2016.csv', delimiter=';', encoding='latin-1')
#radios_17= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Radios-2017.csv', delimiter=',')
#radios_18= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Radios-2018.csv', delimiter=',')
#radios_19= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Radios-2019.csv', delimiter=',')
#mv_16= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Medios-Vecinales-2016.csv', delimiter=';', encoding='latin-1')
#mv_17= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Medios-Vecinales-2017.csv', delimiter=';', encoding='latin-1')
#mv_18= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Medios-Vecinales-2018.csv', delimiter=',')
#mv_19= pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Medios-Vecinales-2019.csv', delimiter=',')
#grafica_16=pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Grafica-2016.csv', delimiter=';')
#grafica_17=pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Grafica-2017.csv', delimiter=';')
#grafica_18=pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Grafica-2018.csv', delimiter=',')
#grafica_19=pd.read_csv(r'C:\Users\lucas\Dropbox\UTN\5° Año\Ciencia de Datos\TP\Publicidad\Datasets\Grafica-2019.csv', delimiter=',')

# %%
#DATASETS NAHUE
#tv_16= pd.read_csv(r'\Users\big_n\python\TV-2016.csv', delimiter=';', encoding='latin-1')
#tv_17= pd.read_csv(r'\Users\big_n\python\tv-2017.csv', delimiter=';', encoding='latin-1')
#tv_18= pd.read_csv(r'\Users\big_n\python\tv-2018.csv', delimiter=',')
#tv_19= pd.read_csv(r'\Users\big_n\python\tv-2019.csv', delimiter=',')
#radios_16= pd.read_csv(r'\Users\big_n\python\radio-2016.csv', delimiter=';', encoding='latin-1')
#radios_17= pd.read_csv(r'\Users\big_n\python\radio-2017.csv', delimiter=',')
#radios_18= pd.read_csv(r'\Users\big_n\python\radio-2018.csv', delimiter=',')
#radios_19= pd.read_csv(r'\Users\big_n\python\radio-2019.csv', delimiter=',')
#mv_16= pd.read_csv(r'\Users\big_n\python\Medios-Vecinales-2016.csv', delimiter=';', encoding='latin-1')
#mv_17= pd.read_csv(r'\Users\big_n\python\medios-vecinales-2017.csv', delimiter=';', encoding='latin-1')
#mv_18= pd.read_csv(r'\Users\big_n\python\medios-vecinales-2018.csv', delimiter=',')
#mv_19= pd.read_csv(r'\Users\big_n\python\medios-vecinales-2019.csv', delimiter=',')
#grafica_16=pd.read_csv(r'\Users\big_n\python\Grafica-2016.csv', delimiter=';')
#grafica_17=pd.read_csv(r'\Users\big_n\python\grafica-2017.csv', delimiter=';')
#grafica_18=pd.read_csv(r'\Users\big_n\python\grafica-2018.csv', delimiter=',')
#grafica_19=pd.read_csv(r'\Users\big_n\python\grafica-2019.csv', delimiter=',')

# %%
#DATASETS DAMI
tv_16= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\TV-2016.csv', delimiter=';', encoding='latin-1')
tv_17= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\TV-2017.csv', delimiter=';', encoding='latin-1')
tv_18= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\TV-2018.csv', delimiter=',')
tv_19= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\TV-2019.csv', delimiter=',')
radios_16= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Radios-2016.csv', delimiter=';')
radios_17= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Radios-2017.csv', delimiter=',')
radios_18= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Radios-2018.csv', delimiter=',')
radios_19= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Radios-2019.csv', delimiter=',')
mv_16= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Medios-Vecinales-2016.csv', delimiter=';', encoding='latin-1')
mv_17= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Medios-Vecinales-2017.csv', delimiter=';', encoding='latin-1')
mv_18= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Medios-Vecinales-2018.csv', delimiter=',')
mv_19= pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Medios-Vecinales-2019.csv', delimiter=',')
grafica_16=pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Grafica-2016.csv', delimiter=';')
grafica_17=pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Grafica-2017.csv', delimiter=';')
grafica_18=pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Grafica-2018.csv', delimiter=',')
grafica_19=pd.read_csv(r'C:\Users\Mariela\Desktop\Dami\ciencia de datos\tp\Datasets\Grafica-2019.csv', delimiter=',')

# %% [markdown]
# ### TV 16

# %%
tv_16.head()
# Out:
#   FECHA_PUBLICACION TIPO        MEDIO   IMPORTE
# 0        01/01/2016   TV           TN  48.000,00
# 1        01/01/2016   TV           TN  48.000,00
# 2        01/01/2016   TV  CANAL METRO  20.000,00
# 3        01/01/2016   TV  CANAL METRO  25.000,00
# 4        01/01/2016   TV   AMERICA 24  31.300,00

# %%
#REEMPLAZO "," POR "." y "." por nada PARA PODER CONVERTIR IMPORTE EN float

tv_16['IMPORTE '] = tv_16['IMPORTE '].str.replace('.','')
tv_16['IMPORTE '] = tv_16['IMPORTE '].str.replace(',','.')
tv_16.head(3)
# Out:
#   FECHA_PUBLICACION TIPO        MEDIO  IMPORTE
# 0        01/01/2016   TV           TN  48000.00
# 1        01/01/2016   TV           TN  48000.00
# 2        01/01/2016   TV  CANAL METRO  20000.00

# %%
# CONVIERTO COLUMNA IMPORTE EN FLOAT

tv_16['IMPORTE '] = tv_16['IMPORTE '].astype(float)

# %%
#REVISO SI HAY VALORES NULOS

tv_16.isnull().sum().sort_values(ascending=False)
# Out:
# IMPORTE              0
# MEDIO                0
# TIPO                 0
# FECHA_PUBLICACION    0
# dtype: int64

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

tv_16.columns=['fecha','tipo','medio','importe']
tv_16.head()
# Out:
#         fecha tipo        medio  importe
# 0  01/01/2016   TV           TN  48000.0
# 1  01/01/2016   TV           TN  48000.0
# 2  01/01/2016   TV  CANAL METRO  20000.0
# 3  01/01/2016   TV  CANAL METRO  25000.0
# 4  01/01/2016   TV   AMERICA 24  31300.0

# %%
#ORDENO COLUMNAS

tv_16=tv_16[['tipo','fecha','medio','importe']]
tv_16.head(3)
# Out:
#   tipo       fecha        medio  importe
# 0   TV  01/01/2016           TN  48000.0
# 1   TV  01/01/2016           TN  48000.0
# 2   TV  01/01/2016  CANAL METRO  20000.0

# %% [markdown]
# ### TV 17

# %%
tv_17.head()
# Out:
#          TIPO       Fecha   Medio    Importe
# 0  TV DE PAGO  29/11/2017  TNT-LA    6747956
# 1  TV ABIERTA  18/04/2017  TELEFE  6036629,5
# 2  TV ABIERTA  18/04/2017  TELEFE    6020960
# 3  TV ABIERTA  07/12/2017  TELEFE    5916186
# 4  TV DE PAGO  01/12/2017  WARNER    5272170

# %%
#REEMPLAZO "," POR "." PARA PODER CONVERTIR IMPORTE EN float

tv_17['Importe'] = tv_17['Importe'].str.replace(',','.')
tv_17.head(3)
# Out:
#          TIPO       Fecha   Medio    Importe
# 0  TV DE PAGO  29/11/2017  TNT-LA    6747956
# 1  TV ABIERTA  18/04/2017  TELEFE  6036629.5
# 2  TV ABIERTA  18/04/2017  TELEFE    6020960

# %%
np.shape(tv_17)
# Out:
# (65535, 4)

# %%
#REVISO SI HAY VALORES NULOS

tv_17.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    64381
# Medio      64381
# Fecha      64381
# TIPO       64381
# dtype: int64

# %%
#ELIMINO VALORES NULOS

tv_17=tv_17.dropna(subset=['Medio'])
tv_17.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    0
# Medio      0
# Fecha      0
# TIPO       0
# dtype: int64

# %%
# CONVIERTO COLUMNA IMPORTE EN FLOAT

tv_17['Importe'] = tv_17['Importe'].astype(float)
tv_17.head()
# Out:
#          TIPO       Fecha   Medio    Importe
# 0  TV DE PAGO  29/11/2017  TNT-LA  6747956.0
# 1  TV ABIERTA  18/04/2017  TELEFE  6036629.5
# 2  TV ABIERTA  18/04/2017  TELEFE  6020960.0
# 3  TV ABIERTA  07/12/2017  TELEFE  5916186.0
# 4  TV DE PAGO  01/12/2017  WARNER  5272170.0

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

tv_17.columns=['tipo','fecha','medio','importe']
tv_17.head()
# Out:
#          tipo       fecha   medio    importe
# 0  TV DE PAGO  29/11/2017  TNT-LA  6747956.0
# 1  TV ABIERTA  18/04/2017  TELEFE  6036629.5
# 2  TV ABIERTA  18/04/2017  TELEFE  6020960.0
# 3  TV ABIERTA  07/12/2017  TELEFE  5916186.0
# 4  TV DE PAGO  01/12/2017  WARNER  5272170.0

# %% [markdown]
# ### TV 18

# %%
tv_18.head()
# Out:
#          tipo       fecha       medio     importe
# 0  TV ABIERTA  2018-01-09    CANAL 13   128986.00
# 1  TV ABIERTA  2018-01-09    CANAL 13  2285627.00
# 2  TV ABIERTA  2018-01-11    CANAL 13   386958.00
# 3  TV ABIERTA  2018-01-12  AMÉRICA TV  1800400.14
# 4  TV ABIERTA  2018-01-12      TELEFE  2416975.00

# %%
tv_18.isnull().sum().sort_values(ascending=False)
# Out:
# importe    0
# medio      0
# fecha      0
# tipo       0
# dtype: int64

# %%
tv_18['importe'] = tv_18['importe'].astype(float)

# %% [markdown]
# ### TV 19

# %%
tv_19.head()
# Out:
#          tipo       fecha       medio     importe
# 0  TV ABIERTA  2019-01-08    CANAL 13   364815,00
# 1  TV ABIERTA  2019-01-08  AMÉRICA TV  1464100,00
# 2  TV ABIERTA  2019-01-08    CANAL 13  2765609,00
# 3  TV ABIERTA  2019-01-18    CANAL 13   441951,00
# 4  TV ABIERTA  2019-01-18    CANAL 13    76230,00

# %%
tv_19.isnull().sum().sort_values(ascending=False)
# Out:
# importe    0
# medio      0
# fecha      0
# tipo       0
# dtype: int64

# %%
tv_19['importe'] = tv_19['importe'].str.replace(',','.')

# %%
tv_19['importe'] = tv_19['importe'].astype(float)
tv_19['fecha'] = tv_19['fecha'].str.replace('-','/')
tv_19.head(3)
# Out:
#          tipo       fecha       medio    importe
# 0  TV ABIERTA  2019/01/08    CANAL 13   364815.0
# 1  TV ABIERTA  2019/01/08  AMÉRICA TV  1464100.0
# 2  TV ABIERTA  2019/01/08    CANAL 13  2765609.0

# %% [markdown]
# ### Radios 16

# %%
radios_16.head()
# Out:
#   FECHA_PUBLICACION   TIPO         MEDIO  IMPORTE
# 0        01/01/2016  RADIO  ROCK AND POP  12300,00
# 1        01/01/2016  RADIO         MITRE  13600,00
# 2        01/01/2016  RADIO         MITRE  10900,00
# 3        01/01/2016  RADIO         MITRE  19000,00
# 4        01/01/2016  RADIO     MILLENIUM  17000,00

# %%
radios_16.isnull().sum().sort_values(ascending=False)
# Out:
# IMPORTE              0
# MEDIO                0
# TIPO                 0
# FECHA_PUBLICACION    0
# dtype: int64

# %%
radios_16['IMPORTE '] = radios_16['IMPORTE '].str.replace(',','.')

# %%
radios_16['IMPORTE ']= radios_16['IMPORTE '].astype(float)
radios_16.head(3)
# Out:
#   FECHA_PUBLICACION   TIPO         MEDIO  IMPORTE
# 0        01/01/2016  RADIO  ROCK AND POP   12300.0
# 1        01/01/2016  RADIO         MITRE   13600.0
# 2        01/01/2016  RADIO         MITRE   10900.0

# %%
# PONGO EN MINUSCULA NOMBRES DE COLUMNAS

radios_16.columns=['fecha','tipo','medio','importe']
radios_16.head()
# Out:
#         fecha   tipo         medio  importe
# 0  01/01/2016  RADIO  ROCK AND POP  12300.0
# 1  01/01/2016  RADIO         MITRE  13600.0
# 2  01/01/2016  RADIO         MITRE  10900.0
# 3  01/01/2016  RADIO         MITRE  19000.0
# 4  01/01/2016  RADIO     MILLENIUM  17000.0

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

radios_16=radios_16[['tipo','fecha','medio','importe']]
radios_16.head(3)
# Out:
#     tipo       fecha         medio  importe
# 0  RADIO  01/01/2016  ROCK AND POP  12300.0
# 1  RADIO  01/01/2016         MITRE  13600.0
# 2  RADIO  01/01/2016         MITRE  10900.0

# %% [markdown]
# ### Radios 17

# %%
radios_17.head()
# Out:
#   FECHA-PUBLICACION   TIPO                MEDIO  IMPORTE
# 0        2017-01-01  RADIO  FM 90.3 Radio Delta   7500.0
# 1        2017-01-01  RADIO  FM 90.3 Radio Delta  33000.0
# 2        2017-01-01  RADIO  FM 90.3 Radio Delta  37500.0
# 3        2017-01-01  RADIO  FM 90.3 Radio Delta  23000.0
# 4        2017-01-01  RADIO  FM 90.3 Radio Delta  18000.0

# %%
radios_17.isnull().sum().sort_values(ascending=False)
# Out:
# IMPORTE              0
# MEDIO                0
# TIPO                 0
# FECHA-PUBLICACION    0
# dtype: int64

# %%
radios_17['IMPORTE'] = radios_17['IMPORTE'].astype(float)

# %%
# CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO ESTA PRIMERO

radios_17=radios_17[['TIPO', 'FECHA-PUBLICACION','MEDIO','IMPORTE']]

# %%
# PONGO EN MINUSCULA NOMBRES DE COLUMNAS

radios_17.columns=['tipo','fecha','medio','importe']
radios_17['fecha'] = radios_17['fecha'].str.replace('-','/')
radios_17.head()
# Out:
#     tipo       fecha                medio  importe
# 0  RADIO  2017/01/01  FM 90.3 Radio Delta   7500.0
# 1  RADIO  2017/01/01  FM 90.3 Radio Delta  33000.0
# 2  RADIO  2017/01/01  FM 90.3 Radio Delta  37500.0
# 3  RADIO  2017/01/01  FM 90.3 Radio Delta  23000.0
# 4  RADIO  2017/01/01  FM 90.3 Radio Delta  18000.0

# %% [markdown]
# ### Radios 18

# %%
radios_18.head()
# Out:
#         fecha               medio    importe am_fm
# 0  2018-01-04       AM 910 LA RED   28250.11    am
# 1  2018-01-08  AM 710 RADIO DIEZ    45980.00    am
# 2  2018-01-08  RADIO MITRE AM 790   62073.00    am
# 3  2018-01-11  AM 710 RADIO DIEZ    81675.00    am
# 4  2018-01-11  RADIO MITRE AM 790  171517.50    am

# %%
radios_18.isnull().sum().sort_values(ascending=False)
# Out:
# am_fm      0
# importe    0
# medio      0
# fecha      0
# dtype: int64

# %%
radios_18['importe'] = radios_18['importe'].astype(float)

# %%
# ELIMINO COLUMNA AM_FM

radios_18=radios_18.drop(columns='am_fm')

# %%
#AGREGO COLUMNA 'TIPO'

radios_18['tipo'] = 'RADIO'

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

radios_18=radios_18[['tipo','fecha','medio','importe']]
radios_18['fecha'] = radios_18['fecha'].str.replace('-','/')
radios_18.head(3)
# Out:
#     tipo       fecha               medio   importe
# 0  RADIO  2018/01/04       AM 910 LA RED  28250.11
# 1  RADIO  2018/01/08  AM 710 RADIO DIEZ   45980.00
# 2  RADIO  2018/01/08  RADIO MITRE AM 790  62073.00

# %% [markdown]
# ### Radios 19

# %%
radios_19.head()
# Out:
#       Fecha                 Medio      Importe
# 0  1/3/2019  AM 1070 - EL MUNDO -   $ 78,200.00
# 1  1/3/2019       FM Cultura 97.9   $ 16,800.00
# 2  1/3/2019       FM Cultura 97.9   $ 19,656.00
# 3  1/3/2019       FM Cultura 97.9   $ 16,800.00
# 4  1/3/2019       FM Cultura 97.9   $ 15,000.00

# %%
radios_19.isnull().sum().sort_values(ascending=False)
# Out:
#   Importe      0
# Medio          0
# Fecha          0
# dtype: int64

# %%
radios_19['  Importe  '] = radios_19['  Importe  '].str.replace('$','')
radios_19['  Importe  '] = radios_19['  Importe  '].str.replace(',','')

# %%
radios_19['  Importe  '] = radios_19['  Importe  '].astype(float)

# %%
#AGREGO COLUMNA TIPO

radios_19['tipo'] = 'RADIO'
radios_19.head(3)
# Out:
#       Fecha                 Medio    Importe     tipo
# 0  1/3/2019  AM 1070 - EL MUNDO -      78200.0  RADIO
# 1  1/3/2019       FM Cultura 97.9      16800.0  RADIO
# 2  1/3/2019       FM Cultura 97.9      19656.0  RADIO

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

radios_19=radios_19[['tipo','Fecha','Medio','  Importe  ']]
radios_19.head(3)
# Out:
#     tipo     Fecha                 Medio    Importe
# 0  RADIO  1/3/2019  AM 1070 - EL MUNDO -      78200.0
# 1  RADIO  1/3/2019       FM Cultura 97.9      16800.0
# 2  RADIO  1/3/2019       FM Cultura 97.9      19656.0

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

radios_19.columns=['tipo','fecha','medio','importe']
radios_19.head(3)
# Out:
#     tipo     fecha                 medio  importe
# 0  RADIO  1/3/2019  AM 1070 - EL MUNDO -  78200.0
# 1  RADIO  1/3/2019       FM Cultura 97.9  16800.0
# 2  RADIO  1/3/2019       FM Cultura 97.9  19656.0

# %% [markdown]
# ### Medios vecinales 16

# %%
mv_16.head()
# Out:
#   FECHA-PUBLICACION              TIPO             MEDIO  IMPORTE
# 0        01/01/2016  MEDIOS VECINALES    AM ONDA LATINA  13346,8
# 1        01/01/2016  MEDIOS VECINALES  FM RADIO GRAFICA  13346,8
# 2        01/01/2016  MEDIOS VECINALES       AM CREATIVA  13346,8
# 3        01/01/2016  MEDIOS VECINALES   FRECUENCIA ZERO  13346,8
# 4        01/01/2016  MEDIOS VECINALES    FM BAJO FLORES  13346,8

# %%
mv_16.isnull().sum().sort_values(ascending=False)
# Out:
# IMPORTE              0
# MEDIO                0
# TIPO                 0
# FECHA-PUBLICACION    0
# dtype: int64

# %%
mv_16['IMPORTE'] = mv_16['IMPORTE'].str.replace(',','.')

# %%
mv_16['IMPORTE']= mv_16['IMPORTE'].astype(float)

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

mv_16.columns=['fecha','tipo','medio','importe']
mv_16.head(3)
# Out:
#         fecha              tipo             medio  importe
# 0  01/01/2016  MEDIOS VECINALES    AM ONDA LATINA  13346.8
# 1  01/01/2016  MEDIOS VECINALES  FM RADIO GRAFICA  13346.8
# 2  01/01/2016  MEDIOS VECINALES       AM CREATIVA  13346.8

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

mv_16=mv_16[['tipo','fecha','medio','importe']]
mv_16.head(3)
# Out:
#                tipo       fecha             medio  importe
# 0  MEDIOS VECINALES  01/01/2016    AM ONDA LATINA  13346.8
# 1  MEDIOS VECINALES  01/01/2016  FM RADIO GRAFICA  13346.8
# 2  MEDIOS VECINALES  01/01/2016       AM CREATIVA  13346.8

# %% [markdown]
# ### Medios vecinales 17

# %%
mv_17.head()
# Out:
#                TIPO      Fecha                             Medio   Importe
# 0  MEDIOS VECINALES  01/01/2017        Villa del Parque Magazine  19185,80
# 1  MEDIOS VECINALES  01/01/2017               Generacion abierta  14389,30
# 2  MEDIOS VECINALES  01/01/2017                   Barrios vacios  14389,30
# 3  MEDIOS VECINALES  01/01/2017                   Antes que nada  14389,30
# 4  MEDIOS VECINALES  01/01/2017  www.lagacetadeversailles.com.ar   9593,00

# %%
mv_17.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    62433
# Medio      62433
# Fecha      62433
# TIPO       62433
# dtype: int64

# %%
mv_17=mv_17.dropna(subset=['Medio'])
mv_17.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    0
# Medio      0
# Fecha      0
# TIPO       0
# dtype: int64

# %%
mv_17['Importe'] = mv_17['Importe'].str.replace(',','.')

# %%
mv_17['Importe'] = mv_17['Importe'].astype(float)

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

mv_17.columns=['tipo','fecha','medio','importe']
mv_17.head(3)
# Out:
#                tipo       fecha                      medio  importe
# 0  MEDIOS VECINALES  01/01/2017  Villa del Parque Magazine  19185.8
# 1  MEDIOS VECINALES  01/01/2017         Generacion abierta  14389.3
# 2  MEDIOS VECINALES  01/01/2017             Barrios vacios  14389.3

# %% [markdown]
# ### Medios vecinales 18

# %%
mv_18.head()
# Out:
#         Fecha                      Medio  Importe
# 0  2018-01-17  www.lapostacapital.com.ar   3198.0
# 1  2018-01-17  www.soybuenosaires.com.ar   3198.0
# 2  2018-01-17        www.megaurbe.com.ar   3198.0
# 3  2018-01-17        www.barriada.com.ar   3198.0
# 4  2018-01-17  www.buenosairessos.com.ar   3198.0

# %%
mv_18.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    0
# Medio      0
# Fecha      0
# dtype: int64

# %%
mv_18['Importe'] = mv_18['Importe'].astype(float)

# %%
#AGREGO COLUMNA TIPO

mv_18['tipo'] = 'MEDIOS VECINALES'
mv_18.head(3)
# Out:
#         Fecha                      Medio  Importe              tipo
# 0  2018-01-17  www.lapostacapital.com.ar   3198.0  MEDIOS VECINALES
# 1  2018-01-17  www.soybuenosaires.com.ar   3198.0  MEDIOS VECINALES
# 2  2018-01-17        www.megaurbe.com.ar   3198.0  MEDIOS VECINALES

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

mv_18=mv_18[['tipo','Fecha','Medio','Importe']]
mv_18.head(3)
# Out:
#                tipo       Fecha                      Medio  Importe
# 0  MEDIOS VECINALES  2018-01-17  www.lapostacapital.com.ar   3198.0
# 1  MEDIOS VECINALES  2018-01-17  www.soybuenosaires.com.ar   3198.0
# 2  MEDIOS VECINALES  2018-01-17        www.megaurbe.com.ar   3198.0

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

mv_18.columns=['tipo','fecha','medio','importe']
mv_18['fecha'] = mv_18['fecha'].str.replace('-','/')
mv_18.head(3)
# Out:
#                tipo       fecha                      medio  importe
# 0  MEDIOS VECINALES  2018/01/17  www.lapostacapital.com.ar   3198.0
# 1  MEDIOS VECINALES  2018/01/17  www.soybuenosaires.com.ar   3198.0
# 2  MEDIOS VECINALES  2018/01/17        www.megaurbe.com.ar   3198.0

# %% [markdown]
# ### Medios vecinales 19

# %%
mv_19.head()
# Out:
#       Fecha                     Medio      Importe
# 0  1/4/2019  EL PERIODICO DE LA GENTE   $ 27,819.40
# 1  1/4/2019               TRAS CARTON   $ 27,819.40
# 2  1/4/2019             TODO PATERNAL   $ 27,819.40
# 3  1/4/2019               LINEA OESTE   $ 27,819.40
# 4  1/4/2019        Panorama Ambiental   $ 20,864.50

# %%
mv_19.isnull().sum().sort_values(ascending=False)
# Out:
#   Importe      0
# Medio          0
# Fecha          0
# dtype: int64

# %%
# Reemplazo "$" y "," y transformo importe en float

mv_19['  Importe  '] = mv_19['  Importe  '].str.replace('$','')
mv_19['  Importe  '] = mv_19['  Importe  '].str.replace(',','')

# %%
mv_19['  Importe  '] = mv_19['  Importe  '].astype(float)
mv_19.head(3)
# Out:
#       Fecha                     Medio    Importe
# 0  1/4/2019  EL PERIODICO DE LA GENTE      27819.4
# 1  1/4/2019               TRAS CARTON      27819.4
# 2  1/4/2019             TODO PATERNAL      27819.4

# %%
#AGREGO COLUMNA TIPO

mv_19['tipo'] = 'MEDIOS VECINALES'
mv_19.head(3)
# Out:
#       Fecha                     Medio    Importe                tipo
# 0  1/4/2019  EL PERIODICO DE LA GENTE      27819.4  MEDIOS VECINALES
# 1  1/4/2019               TRAS CARTON      27819.4  MEDIOS VECINALES
# 2  1/4/2019             TODO PATERNAL      27819.4  MEDIOS VECINALES

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

mv_19=mv_19[['tipo','Fecha','Medio','  Importe  ']]
mv_19.head(3)
# Out:
#                tipo     Fecha                     Medio    Importe
# 0  MEDIOS VECINALES  1/4/2019  EL PERIODICO DE LA GENTE      27819.4
# 1  MEDIOS VECINALES  1/4/2019               TRAS CARTON      27819.4
# 2  MEDIOS VECINALES  1/4/2019             TODO PATERNAL      27819.4

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

mv_19.columns=['tipo','fecha','medio','importe']
mv_19.head(3)
# Out:
#                tipo     fecha                     medio  importe
# 0  MEDIOS VECINALES  1/4/2019  EL PERIODICO DE LA GENTE  27819.4
# 1  MEDIOS VECINALES  1/4/2019               TRAS CARTON  27819.4
# 2  MEDIOS VECINALES  1/4/2019             TODO PATERNAL  27819.4

# %% [markdown]
# ### Grafica 16

# %%
grafica_16.head()
# Out:
#   FECHA-PUBLICACION             TIPO            MEDIO   IMPORTE
# 0        01/01/2016  MEDIOS GRAFICOS        FUNDAMIND     15600
# 1        09/01/2016  MEDIOS GRAFICOS        LA PRENSA  16882,49
# 2        12/01/2016  MEDIOS GRAFICOS        LA PRENSA  16882,49
# 3        12/01/2016  MEDIOS GRAFICOS      EL CRONISTA  41423,93
# 4        14/01/2016  MEDIOS GRAFICOS  AGENDA CULTURAL    108900

# %%
grafica_16.isnull().sum().sort_values(ascending=False)
# Out:
# IMPORTE              0
# MEDIO                0
# TIPO                 0
# FECHA-PUBLICACION    0
# dtype: int64

# %%
grafica_16['IMPORTE'] = grafica_16['IMPORTE'].str.replace(',','.')

# %%
grafica_16['IMPORTE']  = grafica_16['IMPORTE'] .astype(float)
grafica_16.head(3)
# Out:
#   FECHA-PUBLICACION             TIPO      MEDIO   IMPORTE
# 0        01/01/2016  MEDIOS GRAFICOS  FUNDAMIND  15600.00
# 1        09/01/2016  MEDIOS GRAFICOS  LA PRENSA  16882.49
# 2        12/01/2016  MEDIOS GRAFICOS  LA PRENSA  16882.49

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

grafica_16.columns=['fecha','tipo','medio','importe']
grafica_16.head(3)
# Out:
#         fecha             tipo      medio   importe
# 0  01/01/2016  MEDIOS GRAFICOS  FUNDAMIND  15600.00
# 1  09/01/2016  MEDIOS GRAFICOS  LA PRENSA  16882.49
# 2  12/01/2016  MEDIOS GRAFICOS  LA PRENSA  16882.49

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

grafica_16=grafica_16[['tipo','fecha','medio','importe']]
grafica_16.head(3)
# Out:
#               tipo       fecha      medio   importe
# 0  MEDIOS GRAFICOS  01/01/2016  FUNDAMIND  15600.00
# 1  MEDIOS GRAFICOS  09/01/2016  LA PRENSA  16882.49
# 2  MEDIOS GRAFICOS  12/01/2016  LA PRENSA  16882.49

# %%
# CAMBIO LA COLUMNA TIPO PARA QUE SOLO DIGA "GRAFICA"

grafica_16['tipo'] = 'GRAFICA'
grafica_16.head(3)
# Out:
#       tipo       fecha      medio   importe
# 0  GRAFICA  01/01/2016  FUNDAMIND  15600.00
# 1  GRAFICA  09/01/2016  LA PRENSA  16882.49
# 2  GRAFICA  12/01/2016  LA PRENSA  16882.49

# %% [markdown]
# ### Grafica 17

# %%
grafica_17.head()
# Out:
#                          Tipo       Fecha              Medio      Importe
# 0  GRÁFICA / REVISTAS Y OTROS  01/01/2017  Alta AA y Austral  $ 26.562,50
# 1  GRÁFICA / REVISTAS Y OTROS  01/06/2017  Alta AA y Austral  $ 40.294,49
# 2  GRÁFICA / REVISTAS Y OTROS  01/07/2017  Alta AA y Austral  $ 40.294,49
# 3  GRÁFICA / REVISTAS Y OTROS  01/08/2017  Alta AA y Austral  $ 40.294,49
# 4  GRÁFICA / REVISTAS Y OTROS  01/09/2017  Alta AA y Austral  $ 40.294,49

# %%
grafica_17.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    0
# Medio      0
# Fecha      0
# Tipo       0
# dtype: int64

# %%
# Reemplazo "$" ; "," y "."  y transformo importe en float

grafica_17['Importe'] = grafica_17['Importe'].str.replace('$','')
grafica_17['Importe'] = grafica_17['Importe'].str.replace('.','')
grafica_17['Importe'] = grafica_17['Importe'].str.replace(',','.')

# %%
grafica_17['Importe']  = grafica_17['Importe'] .astype(float)
grafica_17.head(3)
# Out:
#                          Tipo       Fecha              Medio   Importe
# 0  GRÁFICA / REVISTAS Y OTROS  01/01/2017  Alta AA y Austral  26562.50
# 1  GRÁFICA / REVISTAS Y OTROS  01/06/2017  Alta AA y Austral  40294.49
# 2  GRÁFICA / REVISTAS Y OTROS  01/07/2017  Alta AA y Austral  40294.49

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

grafica_17.columns=['tipo','fecha','medio','importe']
grafica_17.head(3)
# Out:
#                          tipo       fecha              medio   importe
# 0  GRÁFICA / REVISTAS Y OTROS  01/01/2017  Alta AA y Austral  26562.50
# 1  GRÁFICA / REVISTAS Y OTROS  01/06/2017  Alta AA y Austral  40294.49
# 2  GRÁFICA / REVISTAS Y OTROS  01/07/2017  Alta AA y Austral  40294.49

# %%
# CAMBIO LA COLUMNA TIPO PARA QUE SOLO DIGA "GRAFICA"

grafica_17['tipo'] = 'GRAFICA'
grafica_17.head(3)
# Out:
#       tipo       fecha              medio   importe
# 0  GRAFICA  01/01/2017  Alta AA y Austral  26562.50
# 1  GRAFICA  01/06/2017  Alta AA y Austral  40294.49
# 2  GRAFICA  01/07/2017  Alta AA y Austral  40294.49

# %% [markdown]
# ### Grafica 18

# %%
grafica_18.head()
# Out:
#         Fecha              Medio   Importe
# 0  2018-01-05        EL CRONISTA  18120.36
# 1  2018-01-05        EL CRONISTA  25886.23
# 2  2018-01-05        EL CRONISTA  25886.23
# 3  2018-01-05  AMBITO FINANCIERO  53213.77
# 4  2018-01-09        EL CRONISTA  15531.74

# %%
grafica_18.isnull().sum().sort_values(ascending=False)
# Out:
# Importe    0
# Medio      0
# Fecha      0
# dtype: int64

# %%
grafica_18['Importe']  = grafica_18['Importe'] .astype(float)

# %%
#AGREGO COLUMNA TIPO

grafica_18['tipo'] = 'GRAFICA'
grafica_18.head(3)
# Out:
#         Fecha        Medio   Importe     tipo
# 0  2018-01-05  EL CRONISTA  18120.36  GRAFICA
# 1  2018-01-05  EL CRONISTA  25886.23  GRAFICA
# 2  2018-01-05  EL CRONISTA  25886.23  GRAFICA

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

grafica_18=grafica_18[['tipo','Fecha','Medio','Importe']]
grafica_18.head(3)
# Out:
#       tipo       Fecha        Medio   Importe
# 0  GRAFICA  2018-01-05  EL CRONISTA  18120.36
# 1  GRAFICA  2018-01-05  EL CRONISTA  25886.23
# 2  GRAFICA  2018-01-05  EL CRONISTA  25886.23

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

grafica_18.columns=['tipo','fecha','medio','importe']
grafica_18['fecha'] = grafica_18['fecha'].str.replace('-','/')
grafica_18.head(3)
# Out:
#       tipo       fecha        medio   importe
# 0  GRAFICA  2018/01/05  EL CRONISTA  18120.36
# 1  GRAFICA  2018/01/05  EL CRONISTA  25886.23
# 2  GRAFICA  2018/01/05  EL CRONISTA  25886.23

# %% [markdown]
# ### Grafica 19

# %%
grafica_19.head()
# Out:
#       Fecha          Medio       Importe
# 0  1/3/2019      LA PRENSA    $ 31,651.50
# 1  1/3/2019     OH MY DOG!    $ 50,000.00
# 2  1/3/2019  EL ECONOMISTA    $ 65,000.00
# 3  1/4/2019      LA PRENSA    $ 31,651.50
# 4  1/4/2019         PERFIL   $ 909,741.89

# %%
grafica_18.isnull().sum().sort_values(ascending=False)
# Out:
# importe    0
# medio      0
# fecha      0
# tipo       0
# dtype: int64

# %%
# Reemplazo "$" ; "," y "."  y transformo importe en float

grafica_19['  Importe  '] = grafica_19['  Importe  '].str.replace('$','')
grafica_19['  Importe  '] = grafica_19['  Importe  '].str.replace(',','')

# %%
grafica_19['  Importe  ']  = grafica_19['  Importe  '] .astype(float)
grafica_19.head(3)
# Out:
#       Fecha          Medio    Importe
# 0  1/3/2019      LA PRENSA      31651.5
# 1  1/3/2019     OH MY DOG!      50000.0
# 2  1/3/2019  EL ECONOMISTA      65000.0

# %%
#AGREGO COLUMNA TIPO

grafica_19['tipo'] = 'GRAFICA'
grafica_19.head(3)
# Out:
#       Fecha          Medio    Importe       tipo
# 0  1/3/2019      LA PRENSA      31651.5  GRAFICA
# 1  1/3/2019     OH MY DOG!      50000.0  GRAFICA
# 2  1/3/2019  EL ECONOMISTA      65000.0  GRAFICA

# %%
#CAMBIO EL ORDEN DE LAS COLUMNAS PARA QUE TIPO QUEDE PRIMERO

grafica_19=grafica_19[['tipo','Fecha','Medio','  Importe  ']]
grafica_19.head(3)
# Out:
#       tipo     Fecha          Medio    Importe
# 0  GRAFICA  1/3/2019      LA PRENSA      31651.5
# 1  GRAFICA  1/3/2019     OH MY DOG!      50000.0
# 2  GRAFICA  1/3/2019  EL ECONOMISTA      65000.0

# %%
#CAMBIO NOMBRE COLUMNAS PARA PODER CONCATENAR LUEGO

grafica_19.columns=['tipo','fecha','medio','importe']
grafica_19.head(3)
# Out:
#       tipo     fecha          medio  importe
# 0  GRAFICA  1/3/2019      LA PRENSA  31651.5
# 1  GRAFICA  1/3/2019     OH MY DOG!  50000.0
# 2  GRAFICA  1/3/2019  EL ECONOMISTA  65000.0

# %% [markdown]
# ## Concateno Datasets

# %% [markdown]
# ### TV

# %%
tv = pd.concat([tv_16,tv_17,tv_18,tv_19], axis = 0,  join = "outer" , ignore_index = False) 
tv.head()
# Out:
#   tipo       fecha        medio  importe
# 0   TV  01/01/2016           TN  48000.0
# 1   TV  01/01/2016           TN  48000.0
# 2   TV  01/01/2016  CANAL METRO  20000.0
# 3   TV  01/01/2016  CANAL METRO  25000.0
# 4   TV  01/01/2016   AMERICA 24  31300.0

# %%
tv.tail()
# Out:
#            tipo       fecha       medio     importe
# 970  TV DE PAGO  2019/12/06      WARNER  4268188.85
# 971  TV DE PAGO  2019/12/06         TNT  4655975.94
# 972  TV DE PAGO  2019/12/06        ESPN   609995.70
# 973  TV DE PAGO  2019/12/09  FOX SPORTS   860000.00
# 974  TV DE PAGO  2019/12/18  TyC Sports   500000.00

# %%
# HAGO QUE TODA LA COLUMNA TIPO DIGA TV, SIN IMPORTAR SI ES ABIERTA O PAGA

tv['tipo'] = 'TV'
tv.head(3)
# Out:
#   tipo       fecha        medio  importe
# 0   TV  01/01/2016           TN  48000.0
# 1   TV  01/01/2016           TN  48000.0
# 2   TV  01/01/2016  CANAL METRO  20000.0

# %%
tv.isnull().any()
# Out:
# tipo       False
# fecha      False
# medio      False
# importe    False
# dtype: bool

# %%
np.shape(tv)
# Out:
# (4306, 4)

# %% [markdown]
# ### RADIOS

# %%
radios = pd.concat([radios_16,radios_17,radios_18,radios_19], axis = 0,  join = "outer" , ignore_index = False) 
radios.head()
# Out:
#     tipo       fecha         medio  importe
# 0  RADIO  01/01/2016  ROCK AND POP  12300.0
# 1  RADIO  01/01/2016         MITRE  13600.0
# 2  RADIO  01/01/2016         MITRE  10900.0
# 3  RADIO  01/01/2016         MITRE  19000.0
# 4  RADIO  01/01/2016     MILLENIUM  17000.0

# %%
radios.isnull().any()
# Out:
# tipo       False
# fecha      False
# medio      False
# importe    False
# dtype: bool

# %%
np.shape(radios)
# Out:
# (8848, 4)

# %% [markdown]
# ### MEDIOS VECINALES

# %%
mv = pd.concat([mv_16,mv_17,mv_18,mv_19], axis = 0,  join = "outer" , ignore_index = False) 
mv.head()
# Out:
#                tipo       fecha             medio  importe
# 0  MEDIOS VECINALES  01/01/2016    AM ONDA LATINA  13346.8
# 1  MEDIOS VECINALES  01/01/2016  FM RADIO GRAFICA  13346.8
# 2  MEDIOS VECINALES  01/01/2016       AM CREATIVA  13346.8
# 3  MEDIOS VECINALES  01/01/2016   FRECUENCIA ZERO  13346.8
# 4  MEDIOS VECINALES  01/01/2016    FM BAJO FLORES  13346.8

# %%
mv.isnull().any()
# Out:
# tipo       False
# fecha      False
# medio      False
# importe    False
# dtype: bool

# %%
np.shape(mv)
# Out:
# (13324, 4)

# %% [markdown]
# ### GRAFICA

# %%
grafica = pd.concat([grafica_16,grafica_17,grafica_18,grafica_19], axis = 0,  join = "outer" , ignore_index = False) 
grafica.head()
# Out:
#       tipo       fecha            medio    importe
# 0  GRAFICA  01/01/2016        FUNDAMIND   15600.00
# 1  GRAFICA  09/01/2016        LA PRENSA   16882.49
# 2  GRAFICA  12/01/2016        LA PRENSA   16882.49
# 3  GRAFICA  12/01/2016      EL CRONISTA   41423.93
# 4  GRAFICA  14/01/2016  AGENDA CULTURAL  108900.00

# %%
grafica.isnull().any()
# Out:
# tipo       False
# fecha      False
# medio      False
# importe    False
# dtype: bool

# %%
np.shape(grafica)
# Out:
# (2796, 4)

# %% [markdown]
# ### CONCATENO LOS 4 DATASETS

# %%
publicidad = pd.concat([tv,radios,mv,grafica], axis = 0,  join = "outer" , ignore_index = False) 
publicidad.head(3)
# Out:
#   tipo       fecha        medio  importe
# 0   TV  01/01/2016           TN  48000.0
# 1   TV  01/01/2016           TN  48000.0
# 2   TV  01/01/2016  CANAL METRO  20000.0

# %%
publicidad.isnull().any()
# Out:
# tipo       False
# fecha      False
# medio      False
# importe    False
# dtype: bool

# %%
np.shape(publicidad)
# Out:
# (29274, 4)

# %%
#CREO COLUMNA ANIO

publicidad.fecha = pd.to_datetime(publicidad.fecha)
publicidad['anio'] = publicidad.fecha.dt.year
publicidad.head(3)
# Out:
#   tipo      fecha        medio  importe  anio
# 0   TV 2016-01-01           TN  48000.0  2016
# 1   TV 2016-01-01           TN  48000.0  2016
# 2   TV 2016-01-01  CANAL METRO  20000.0  2016

# %%
# CREO COLUMNA MES

publicidad.fecha = pd.to_datetime(publicidad.fecha)
publicidad['mes'] = publicidad.fecha.dt.month
publicidad.head(3)
# Out:
#   tipo      fecha        medio  importe  anio  mes
# 0   TV 2016-01-01           TN  48000.0  2016    1
# 1   TV 2016-01-01           TN  48000.0  2016    1
# 2   TV 2016-01-01  CANAL METRO  20000.0  2016    1

# %%
# AGREGO COLUMNA ANIO - MES

publicidad['anio_mes'] = pd.to_datetime(publicidad['fecha']).dt.to_period('M')
publicidad.head(3)
# Out:
#   tipo      fecha        medio  importe  anio  mes anio_mes
# 0   TV 2016-01-01           TN  48000.0  2016    1  2016-01
# 1   TV 2016-01-01           TN  48000.0  2016    1  2016-01
# 2   TV 2016-01-01  CANAL METRO  20000.0  2016    1  2016-01

# %%
#SACO EL DIA DE LA FECHA Y DEJO SOLO ANIO/MES

#publicidad.fecha = pd.to_datetime(publicidad.fecha).dt.strftime('%Y/%m')
#publicidad.head(3)

#REEMPLACE ESTE POR EN ANTERIOR

# %%
# MUEVO COLUMNA ANIO Y ANIO-MES QUEDO EL DATASET LISTO PARA ANALIZAR NOMAS

publicidad=publicidad[['tipo','anio','mes','anio_mes','fecha','medio','importe']]
publicidad
# Out:
#         tipo  anio  mes anio_mes      fecha               medio    importe
# 0         TV  2016    1  2016-01 2016-01-01                  TN   48000.00
# 1         TV  2016    1  2016-01 2016-01-01                  TN   48000.00
# 2         TV  2016    1  2016-01 2016-01-01         CANAL METRO   20000.00
# 3         TV  2016    1  2016-01 2016-01-01         CANAL METRO   25000.00
# 4         TV  2016    1  2016-01 2016-01-01          AMERICA 24   31300.00
# ..       ...   ...  ...      ...        ...                 ...        ...
# 547  GRAFICA  2019   12  2019-12 2019-12-30         REVISTA VPT   30000.00
# 548  GRAFICA  2019   12  2019-12 2019-12-30  Diario de la Salud  512282.86
# 549  GRAFICA  2019   12  2019-12 2019-12-30     ANUARIO DOSSIER   25266.25
# 550  GRAFICA  2019   12  2019-12 2019-12-30         EL CRONISTA   87943.43
# 551  GRAFICA  2019   12  2019-12 2019-12-30           LA NACIÓN  471279.02
#
# [29274 rows x 7 columns]

# %%
publicidad.importe=publicidad.importe/1000000

# %%
publicidad.columns=['tipo','anio','mes','anio_mes','fecha','medio','importe en millones']
publicidad.head(20)
# Out:
#    tipo  anio  mes anio_mes      fecha        medio  importe en millones
# 0    TV  2016    1  2016-01 2016-01-01           TN             0.048000
# 1    TV  2016    1  2016-01 2016-01-01           TN             0.048000
# 2    TV  2016    1  2016-01 2016-01-01  CANAL METRO             0.020000
# 3    TV  2016    1  2016-01 2016-01-01  CANAL METRO             0.025000
# 4    TV  2016    1  2016-01 2016-01-01   AMERICA 24             0.031300
# 5    TV  2016    1  2016-01 2016-01-01      CANAL 9             0.130000
# 6    TV  2016    1  2016-01 2016-01-27   AMERICA TV             0.065340
# 7    TV  2016    1  2016-01 2016-01-02           TN             0.048000
# 8    TV  2016    1  2016-01 2016-01-02           TN             0.048000
# 9    TV  2016    1  2016-01 2016-01-02  CANAL METRO             0.020000
# 10   TV  2016    1  2016-01 2016-01-02  CANAL METRO             0.025000
# 11   TV  2016    1  2016-01 2016-01-02   AMERICA 24             0.031300
# ...

# %%
#reemplazo america tv que está escrito de distintas formas
publicidad['medio'] = publicidad['medio'].str.replace('América tv','AMÉRICA TV')

# %% [markdown]
# # EDA

# %%
# veo cuanta cantidad de datos hay de cada tipo de publicidad

idx = publicidad['tipo'].value_counts(ascending=False).index[0:]

plt.figure(figsize=(12,4))
j = sns.countplot(x="tipo", data=publicidad, order=idx)
plt.title('Cantidad Publicidades por Tipo de Publicidad', size = 25)
plt.xlabel("Tipo de Publicidad", size = 20)
plt.ylabel("Cantidades", size = 20)
plt.show()

# %% [markdown]
# ### AGRUPO POR TIPO DE PUBLICIDAD

# %%
publicidad_portipo = publicidad.groupby(["tipo"])["importe en millones"].sum()
publicidad_portipo.head()
# Out:
# tipo
# GRAFICA              549.895820
# MEDIOS VECINALES     204.597496
# RADIO                465.067777
# TV                  1837.464916
# Name: importe en millones, dtype: float64

# %%
plt.figure(figsize=(8,5))
publicidad_portipo.plot.bar(x="tipo", y="importe en millones")
plt.xticks(rotation=0)
plt.xlabel("Tipo de Publicidad", size = 20)
plt.ylabel("Importe en Millones", size = 20)
plt.title("Importe por Tipo de Publicidad", size = 25)
# Podemos ver que en la tv es la segunda categoria donde menos cantidad de publicidades hay, 
# pero es la que tiene mayor importe
# Out:
# Text(0.5, 1.0, 'Importe por Tipo de Publicidad')

# %% [markdown]
# ## Analizamos TV por ser el Tipo de medio con mayor inversion a lo largo de los años

# %%
#CREO COLUMNA ANIO
tv.fecha = pd.to_datetime(tv.fecha)
tv['anio'] = tv.fecha.dt.year

# %%
# CREO COLUMNA MES
tv.fecha = pd.to_datetime(tv.fecha)
tv['mes'] = tv.fecha.dt.month

# %%
tv.columns=['tipo','fecha','medio','importe en millones','anio','mes']
tv.head()
# Out:
#   tipo      fecha        medio  importe en millones  anio  mes
# 0   TV 2016-01-01           TN              48000.0  2016    1
# 1   TV 2016-01-01           TN              48000.0  2016    1
# 2   TV 2016-01-01  CANAL METRO              20000.0  2016    1
# 3   TV 2016-01-01  CANAL METRO              25000.0  2016    1
# 4   TV 2016-01-01   AMERICA 24              31300.0  2016    1

# %%
tv['importe en millones']=tv['importe en millones']/1000000
tv.columns=['tipo','fecha','medio','importe en millones','anio','mes']
tv.head(3)
# Out:
#   tipo      fecha        medio  importe en millones  anio  mes
# 0   TV 2016-01-01           TN                0.048  2016    1
# 1   TV 2016-01-01           TN                0.048  2016    1
# 2   TV 2016-01-01  CANAL METRO                0.020  2016    1

# %%
tv.shape
# Out:
# (4306, 6)

# %%
plt.figure(figsize=(20,5))

ax = sns.boxplot(x="anio", y="importe en millones", data=tv, palette='mako')
plt.show()

# %%
fig, axes = plt.subplots(4, figsize=(15,10), sharey=True)

sns.boxplot(ax=axes[0], x="mes", y="importe en millones",
            data=tv.loc[tv['anio']== 2016], palette='mako')

axes[0].set_title(2016)

sns.boxplot(ax=axes[1], x="mes", y="importe en millones",
            data=tv.loc[tv['anio']== 2017], palette='mako')

axes[1].set_title(2017)

sns.boxplot(ax=axes[2], x="mes", y="importe en millones",
            data=tv.loc[tv['anio']== 2018], palette='mako')

axes[2].set_title(2018)

sns.boxplot(ax=axes[3], x="mes", y="importe en millones",
            data=tv.loc[tv['anio']== 2019], palette='mako')

axes[3].set_title(2019)

plt.show()

# A continuación podemos un boxplot año tras año para la TV
# Podemos ver que a medida que los años fueron avanzando, un aumento progresivo de outliers

# %%
plt.figure(figsize=(25,5))

ax =sns.countplot(x="medio",
                  data=tv,
                  order=tv.medio.value_counts().index,  palette='mako')

ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right" )

plt.show()

# En este grafico podemos ver la cantidad de publicidad realizada en cada medio de TV a lo largo de los años,
# sin tener en cuenta el importe
# Out:
# C:\Users\Mariela\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Mariela\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#En los próximos graficos, se podra apreciar el importe total invertido en cada medio para cada uno de los 4 años contemplados

plt.figure(figsize=(15,5))

ax =sns.barplot(x = tv.loc[tv['anio']== 2016]['medio'],
                y = tv.loc[tv['anio']== 2016]['importe en millones'], # .sum()
                data=tv.loc[tv['anio']== 2016] ,
                palette='mako',
                ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right" )

plt.show()

# %%
plt.figure(figsize=(15,5))

ax =sns.barplot(x = tv.loc[tv['anio']== 2017]['medio'],
                y = tv.loc[tv['anio']== 2017]['importe en millones'], # .sum()
                data=tv.loc[tv['anio']== 2017] ,
                palette='mako',
                ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right" )

plt.show()

# %%
plt.figure(figsize=(15,5))

ax =sns.barplot(x = tv.loc[tv['anio']== 2018]['medio'],
                y = tv.loc[tv['anio']== 2018]['importe en millones'], # .sum()
                data=tv.loc[tv['anio']== 2018] ,
                palette='mako',
                ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right" )

plt.show()

# %%
plt.figure(figsize=(15,5))

ax =sns.barplot(x = tv.loc[tv['anio']== 2019]['medio'],
                y = tv.loc[tv['anio']== 2019]['importe en millones'], # .sum()
                data=tv.loc[tv['anio']== 2019] ,
                palette='mako',
                ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right" )

plt.show()

# %% [markdown]
# ## ANALISIS ANUAL

# %%
publicidad_poraño = publicidad.groupby(["anio"])["importe en millones"].sum()
publicidad_poraño.head()
# Out:
# anio
# 2016     485.862158
# 2017     671.871155
# 2018     810.707214
# 2019    1088.585482
# Name: importe en millones, dtype: float64

# %%
sns.set_context("talk", font_scale=.9)
publicidad_poraño.plot.bar()
plt.title('Importe en Millones por Año', size = 20)
plt.xlabel("Año", size = 15)
plt.ylabel("Importe en Millones", size = 15)
plt.show()

# %%
# Podemos notar que, en terminos reales la inversión en publicidad decreció contemplando la inflacion

# %% [markdown]
# #### Analisis anual para TV

# %%
publicidad_poraño_tv = tv.groupby(["anio"])["importe en millones"].sum()
publicidad_poraño_tv.head()
# Out:
# anio
# 2016    272.308554
# 2017    408.428319
# 2018    470.592015
# 2019    686.136028
# Name: importe en millones, dtype: float64

# %%
sns.set_context("talk", font_scale=.9)
publicidad_poraño_tv.plot.bar()
plt.title('Importe en Millones por Año TV', size = 20)
plt.xlabel("Año", size = 15)
plt.ylabel("Importe en Millones", size = 15)
plt.show()

# %% [markdown]
# #### Analisis anual para Radios

# %%
#CREO COLUMNA ANIO
radios.fecha = pd.to_datetime(radios.fecha)
radios['anio'] = radios.fecha.dt.year

# CREO COLUMNA MES
radios.fecha = pd.to_datetime(radios.fecha)
radios['mes'] = radios.fecha.dt.month

radios.columns=['tipo','fecha','medio','importe en millones','anio','mes']
radios.head()


radios['importe en millones']=radios['importe en millones']/1000000
radios.columns=['tipo','fecha','medio','importe en millones','anio','mes']
radios.head(3)
# Out:
#     tipo      fecha         medio  importe en millones  anio  mes
# 0  RADIO 2016-01-01  ROCK AND POP               0.0123  2016    1
# 1  RADIO 2016-01-01         MITRE               0.0136  2016    1
# 2  RADIO 2016-01-01         MITRE               0.0109  2016    1

# %%
publicidad_poraño_radios = radios.groupby(["anio"])["importe en millones"].sum()
publicidad_poraño_radios.head()

sns.set_context("talk", font_scale=.9)
publicidad_poraño_radios.plot.bar()
plt.title('Importe en Millones por Año Radios', size = 20)
plt.xlabel("Año", size = 15)
plt.ylabel("Importe en Millones", size = 15)
plt.show()

# %% [markdown]
# #### Analisis anual para Graficas

# %%
#CREO COLUMNA ANIO
grafica.fecha = pd.to_datetime(grafica.fecha)
grafica['anio'] = grafica.fecha.dt.year

# CREO COLUMNA MES
grafica.fecha = pd.to_datetime(grafica.fecha)
grafica['mes'] = grafica.fecha.dt.month

grafica.columns=['tipo','fecha','medio','importe en millones','anio','mes']
grafica.head()


grafica['importe en millones']=grafica['importe en millones']/1000000
grafica.columns=['tipo','fecha','medio','importe en millones','anio','mes']
grafica.head(3)
# Out:
#       tipo      fecha      medio  importe en millones  anio  mes
# 0  GRAFICA 2016-01-01  FUNDAMIND             0.015600  2016    1
# 1  GRAFICA 2016-09-01  LA PRENSA             0.016882  2016    9
# 2  GRAFICA 2016-12-01  LA PRENSA             0.016882  2016   12

# %%
publicidad_poraño_grafica = grafica.groupby(["anio"])["importe en millones"].sum()
publicidad_poraño_grafica.head()

sns.set_context("talk", font_scale=.9)
publicidad_poraño_grafica.plot.bar()
plt.title('Importe en Millones por Año Grafica', size = 20)
plt.xlabel("Año", size = 15)
plt.ylabel("Importe en Millones", size = 15)
plt.show()

# %% [markdown]
# #### Analisis anual para Medios Vecinales

# %%
#CREO COLUMNA ANIO
mv.fecha = pd.to_datetime(mv.fecha)
mv['anio'] = mv.fecha.dt.year

# CREO COLUMNA MES
mv.fecha = pd.to_datetime(mv.fecha)
mv['mes'] = mv.fecha.dt.month

mv.columns=['tipo','fecha','medio','importe en millones','anio','mes']
mv.head()


mv['importe en millones']=mv['importe en millones']/1000000
mv.columns=['tipo','fecha','medio','importe en millones','anio','mes']
mv.head(3)
# Out:
#                tipo      fecha             medio  importe en millones  anio  \
# 0  MEDIOS VECINALES 2016-01-01    AM ONDA LATINA             0.013347  2016
# 1  MEDIOS VECINALES 2016-01-01  FM RADIO GRAFICA             0.013347  2016
# 2  MEDIOS VECINALES 2016-01-01       AM CREATIVA             0.013347  2016
#
#    mes
# 0    1
# 1    1
# 2    1

# %%
publicidad_poraño_mv = mv.groupby(["anio"])["importe en millones"].sum()
publicidad_poraño_mv.head()
# Out:
# anio
# 2016    33.331733
# 2017    43.201277
# 2018    50.170706
# 2019    77.893780
# Name: importe en millones, dtype: float64

# %%
sns.set_context("talk", font_scale=.9)
publicidad_poraño_mv.plot.bar()
plt.title('Importe en Millones por Año Medios Vecinales', size = 20)
plt.xlabel("Año", size = 15)
plt.ylabel("Importe en Millones", size = 15)
plt.show()

# %%
# En todos los tipos de medios se vio un incremento anual en la inversion en publicidad
# Esto pudo haberse debido al contexto inflacionario que se vive en Argentina, ademas de otras causas, como pudieron haber sido
# las elecciones de 2017 y 2019
# El unico tipo de medio en el que no se vio un incremento nominal significativo de 2018 a 2019 (año de elecciones presidenciales)
# fue en Grafica

# %% [markdown]
# ## Analisis mensual

# %%
publicidad_porañomes = publicidad.groupby(["anio_mes"])["importe en millones"].sum()
publicidad_porañomes.head(3)
# Out:
# anio_mes
# 2016-01    137.968833
# 2016-02     30.129924
# 2016-03     59.333321
# Freq: M, Name: importe en millones, dtype: float64

# %%
plt.figure(figsize=(12,5))
sns.set_context("talk", font_scale=.5)
publicidad_porañomes.plot.bar()
plt.title('Importe en Millones por Mes', size = 25)
plt.xlabel("Año-Mes", size = 20)
plt.ylabel("Importe en Millones", size = 20)
plt.show()

# %% [markdown]
# ## Correlacion

# %%
publicidad_c = pd.pivot_table(publicidad,values = 'importe en millones',columns = 'tipo', index = 'anio_mes', aggfunc = np.sum)
publicidad_c.head()
# Out:
# tipo       GRAFICA  MEDIOS VECINALES      RADIO         TV
# anio_mes
# 2016-01   6.491761         33.331733  38.391014  59.754325
# 2016-02   2.115550               NaN   5.380659  22.633715
# 2016-03   8.755241               NaN   5.449586  45.128494
# 2016-04   5.438351               NaN   9.834574  21.524522
# 2016-05   7.026159               NaN   2.577477  18.322165

# %%
# CREO UNA MATRIZ DE CORRELACION PEARSON ENTRE CADA TIPO DE MEDIO

publicidad_c_corr=publicidad_c.corr()

# %%
publicidad_c_corr.head()
# Out:
# tipo               GRAFICA  MEDIOS VECINALES     RADIO        TV
# tipo
# GRAFICA           1.000000         -0.019056  0.486767  0.551957
# MEDIOS VECINALES -0.019056          1.000000  0.391877  0.278921
# RADIO             0.486767          0.391877  1.000000  0.691554
# TV                0.551957          0.278921  0.691554  1.000000

# %%
publicidad_c_corr.shape
# Out:
# (4, 4)

# %%
sns.heatmap(publicidad_c_corr, annot=True, cmap=sns.diverging_palette(240, 10, as_cmap=True))
plt.title("Matriz de correlacion entre tipos de medios")
plt.show()

# %%
# MEDIOS VECINALES NO SE CORRELACIONA CON NINGUNO DE LOS OTROS TIPOS DE PUBLICIDAD
# lA MAYOR CORRELACIÓN SE DA ENTRE TV Y RADIO CON UNA R DE 0,69

# %%
# PAIRPLOT PARA VISUALIZAR LA RELACION ENTRE MEDIOS

plt.figure(figsize=(10,10))
sns.pairplot(publicidad_c)
plt.xticks(rotation=70)
plt.show()

# CADA PUNTO REPRESENTA UN MES DISTINTO CON SU IMPORTE EN AMBOS FEATURES, EN EL QUE PODEMOS APRECIAR GRAFICAMENTE LO QUE NOS ENSEÑABA EL HEATMAP

# %% [markdown]
# ## Datos Estadisticos

# %%
publicidad['importe en millones'].describe()
# Out:
# count    29274.000000
# mean         0.104428
# std          0.418426
# min          0.000000
# 25%          0.011511
# 50%          0.016692
# 75%          0.033747
# max          8.878073
# Name: importe en millones, dtype: float64

# %%
# Podemos ver que la publicidad mas cara es de casi $9 millones en CANAL 9, en Septiembre de 2019
# Esta fecha es muy cercana a las elecciones presidenciales
publicidad[publicidad['importe en millones'] > 8.5]
# Out:
#     tipo  anio  mes anio_mes      fecha    medio  importe en millones
# 234   TV  2019    9  2019-09 2019-09-13  CANAL 9             8.878073

# %% [markdown]
# ### CUANTIL 0.95

# %%
# CALCULO CUANTIL 95 PARA LA COLUMNA IMPORTES
percentil_95 = publicidad['importe en millones'].quantile(0.95)
percentil_95
# Out:
# 0.41361091

# %% [markdown]
# ### Cuantil 0.05

# %%
# CALCULO CUANTIL 05 PARA LA COLUMNA IMPORTES
percentil_05 = publicidad['importe en millones'].quantile(0.05)
percentil_05
# Out:
# 0.0072

# %%
#DEFINO COMO PUBLICIDAD COSTOSA A TODO LO QUE ESTE ARRIBA DEL PERCENTIL 95
publicidad_costosa=publicidad.loc[publicidad['importe en millones']>percentil_95]

# %%
#DEFINO COMO PUBLICIDAD NORMAL A TODO LO QUE ESTE DEBAJO DEL PERCENTIL 95 y POR ENCIMA DEL PERCENTIL 05
publicidad_normal=publicidad.loc[(publicidad['importe en millones']>=percentil_05) & (publicidad['importe en millones']<=percentil_95)]
publicidad_normal.head()
# Out:
#   tipo  anio  mes anio_mes      fecha        medio  importe en millones
# 0   TV  2016    1  2016-01 2016-01-01           TN               0.0480
# 1   TV  2016    1  2016-01 2016-01-01           TN               0.0480
# 2   TV  2016    1  2016-01 2016-01-01  CANAL METRO               0.0200
# 3   TV  2016    1  2016-01 2016-01-01  CANAL METRO               0.0250
# 4   TV  2016    1  2016-01 2016-01-01   AMERICA 24               0.0313

# %%
np.shape(publicidad_costosa)
# Out:
# (1462, 7)

# %%
np.shape(publicidad_normal)
# Out:
# (26457, 7)

# %%
publicidad_costosa['importe en millones'].describe()
# Out:
# count    1462.000000
# mean        1.351439
# std         1.338346
# min         0.413820
# 25%         0.570523
# 50%         0.826718
# 75%         1.529156
# max         8.878073
# Name: importe en millones, dtype: float64

# %%
publicidad_normal['importe en millones'].describe()
# Out:
# count    26457.000000
# mean         0.040565
# std          0.065555
# min          0.007200
# 25%          0.011522
# 50%          0.016692
# 75%          0.029300
# max          0.413611
# Name: importe en millones, dtype: float64

# %%
# AGRUPO POR TIPO EL IMPORTE EN PUBLICIDAD EFECTUADO PARA "PUBLICIDAD CARA"

publicidad_costosa1 = publicidad_costosa.groupby(["tipo"])["importe en millones"].sum()
publicidad_costosa1.head(3)
# Out:
# tipo
# GRAFICA     285.474151
# RADIO       129.539083
# TV         1560.790589
# Name: importe en millones, dtype: float64

# %%
plt.figure(figsize=(5,5))
publicidad_costosa1.plot.bar()
plt.title('Publicidad "Costosa"', size = 20)
plt.xlabel("Tipo", size = 12)
plt.ylabel("Importe en Millones", size = 12)
# Out:
# Text(0, 0.5, 'Importe en Millones')

# %%
# Podemos ver que casi toda la publicidad por encima del percentil 95, es publicidad en TV
# Esto se debe a los precios elevados de la misma

# %%
# AGRUPO POR TIPO EL IMPORTE EN PUBLICIDAD EFECTUADO PARA "PUBLICIDAD NORMAL"

publicidad_normal1 = publicidad_normal.groupby(["tipo"])["importe en millones"].sum()
publicidad_normal1.head(3)
# Out:
# tipo
# GRAFICA             264.296278
# MEDIOS VECINALES    201.215326
# RADIO               331.864532
# Name: importe en millones, dtype: float64

# %%
publicidad_normal1.plot.bar()
plt.title('Publicidad "Normal"', size = 20)
plt.xlabel("Tipo", size = 12)
plt.ylabel("Importe en Millones", size = 12)
# Out:
# Text(0, 0.5, 'Importe en Millones')

# %%
# En este caso, se ve un grafico mucho mas equilibrado debido a la eliminacion de los outliers
# La mayor parte de la inversion en TV se da por "Publicidades Costosas"

# %% [markdown]
# ### CUANTIL 0.05

# %%
#DEFINO COMO PUBLICIDAD ECONOMICA A TODO LO QUE ESTE DEBAJO DEL PERCENTIL 05
publicidad_economica=publicidad.loc[publicidad['importe en millones']<percentil_05]

# %%
np.shape(publicidad_economica)
# Out:
# (1355, 7)

# %%
publicidad_economica['importe en millones'].describe()
# Out:
# count    1355.000000
# mean        0.005897
# std         0.001112
# min         0.000000
# 25%         0.005250
# 50%         0.006480
# 75%         0.006673
# max         0.007169
# Name: importe en millones, dtype: float64

# %%
# AGRUPO POR TIPO EL IMPORTE EN PUBLICIDAD EFECTUADO PARA "PUBLICIDAD ECONOMICA"

publicidad_economica = publicidad_economica.groupby(["tipo"])["importe en millones"].sum()
publicidad_economica.head(3)
# Out:
# tipo
# GRAFICA             0.125391
# MEDIOS VECINALES    3.382169
# RADIO               3.664163
# Name: importe en millones, dtype: float64

# %%
plt.figure(figsize=(5,5))
publicidad_economica.plot.bar()
plt.title('Publicidad "Economica"', size = 20)
plt.xlabel("Tipo", size = 15)
plt.ylabel("Importe en Millones", size = 15)
# Out:
# Text(0, 0.5, 'Importe en Millones')

# %%
# En lo que respecta a publicidades debajo sel cuantil 0.05, la mayor parte de inversion en publicidad es destinada a 
# Medios vecinales y Radio
